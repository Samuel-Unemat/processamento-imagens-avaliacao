# %% [markdown]
# <a href="https://colab.research.google.com/github/Samuel-Unemat/processamento-imagens-avaliacao/blob/main/atividade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python numpy matplotlib
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
repo_url = "https://github.com/Samuel-Unemat/processamento-imagens-avaliacao"

# !git clone {repo_url}
# Out:
# fatal: destination path 'processamento-imagens-avaliacao' already exists and is not an empty directory.

# %%
base_path = "/content/processamento-imagens-avaliacao/Imagem"

# Lista todas as imagens da pasta
imagens = os.listdir(base_path)

print("Imagens encontradas:", imagens)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9498/939225698.py in <cell line: 0>()
#       2
#       3 # Lista todas as imagens da pasta
# ----> 4 imagens = os.listdir(base_path)
#       5
#       6 print("Imagens encontradas:", imagens)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/processamento-imagens-avaliacao/Imagem'

# %%
img_path = os.path.join(base_path, "imagem1.jpg")

img = cv2.imread(img_path)

# Verificação
if img is None:
    print("Erro ao carregar a imagem. Verifique o nome/caminho.")
else:
    print("Imagem carregada com sucesso!")
# Out:
# Imagem carregada com sucesso!

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title("Imagem carregada do GitHub")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %%
imgs = []

for nome in imagens:
    caminho = os.path.join(base_path, nome)
    imagem = cv2.imread(caminho)

    if imagem is not None:
        imgs.append(imagem)

print(f"{len(imgs)} imagens carregadas com sucesso!")
# Out:
# 1 imagens carregadas com sucesso!

# %%
for i, imagem in enumerate(imgs):
    plt.figure()
    plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
    plt.title(f"Imagem {i+1}")
    plt.axis('off')

# %%
## Exercício 01 - Descrição
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.title("Imagem Original")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %%
## Exercício 02 - Descrição
print("Shape:", img.shape)
print("Size:", img.size)
print("Dtype:", img.dtype)
# Out:
# Shape: (1280, 960, 3)
# Size: 3686400
# Dtype: uint8

# %%
## Exercício 03 - Descrição
cv2.imwrite('imagem_convertida.jpg', img)
# Out:
# True

# %%
## Exercício 04 - Descrição
h, w, _ = img.shape
centro = img[h//2, w//2]
print("Pixel central (BGR):", centro)
# Out:
# Pixel central (BGR): [ 35  35 105]

# %%
## Exercício 05 - Descrição
img_mod = img.copy()
img_mod[0:100, 0:100] = (0, 255, 0)

plt.imshow(cv2.cvtColor(img_mod, cv2.COLOR_BGR2RGB))
plt.title("Região modificada")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %%
## Exercício 06 - Descrição
roi = img[100:300, 100:300]

plt.imshow(cv2.cvtColor(roi, cv2.COLOR_BGR2RGB))
plt.title("Recorte (ROI)")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(199.5), np.float64(-0.5))

# %%
## Exercício 07 - Descrição
b, g, r = cv2.split(img)

# %%
## Exercício 08 - Descrição
plt.imshow(g, cmap='gray')
plt.title("Canal Verde")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %%
## Exercício 09 - Descrição
img_merge = cv2.merge([r, g, b])
plt.imshow(img_merge)
plt.title("Canais invertidos (R ↔ B)")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %%
## Exercício 10 - Descrição
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')
plt.title("Escala de Cinza")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %%
## Exercício 11 - Descrição
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
s = hsv[:, :, 1]

plt.imshow(s, cmap='gray')
plt.title("Canal Saturação (S)")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %%
## Exercício 12 - Descrição
bright = cv2.add(img, np.ones(img.shape, dtype='uint8') * 50)

plt.imshow(cv2.cvtColor(bright, cv2.COLOR_BGR2RGB))
plt.title("Imagem com brilho aumentado")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %%
## Exercício 13 - Descrição
img2 = cv2.resize(img, (img.shape[1], img.shape[0]))

blend = cv2.addWeighted(img, 0.5, img2, 0.5, 0)

plt.imshow(cv2.cvtColor(blend, cv2.COLOR_BGR2RGB))
plt.title("Mesclagem de imagens")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %%
## Exercício 14 - Descrição
neg = 255 - gray

plt.imshow(neg, cmap='gray')
plt.title("Negativo")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %%
## Exercício 15 - Descrição
mask = np.zeros(gray.shape, dtype='uint8')
cv2.circle(mask, (w//2, h//2), 100, 255, -1)

res = cv2.bitwise_and(img, img, mask=mask)

plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))
plt.title("Máscara circular")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %%
## Exercício 16 - Descrição
small = cv2.resize(img, None, fx=0.3, fy=0.3)
print("Novo shape:", small.shape)
# Out:
# Novo shape: (384, 288, 3)

# %%
## Exercício 17 - Descrição
hist = cv2.calcHist([gray], [0], None, [256], [0, 256])
print("Histograma (primeiros valores):")
print(hist[:10])
# Out:
# Histograma (primeiros valores):
# [[ 3765.]
#  [ 8436.]
#  [ 8852.]
#  [ 9259.]
#  [ 9374.]
#  [ 7732.]
#  [ 7815.]
#  [10276.]
#  [10247.]
#  [10516.]]

# %%
## Exercício 18 - Descrição
colors = ('b', 'g', 'r')

for i, col in enumerate(colors):
    hist = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(hist)

plt.title("Histograma RGB")
plt.show()

# %%
## Exercício 19 - Descrição
eq = cv2.equalizeHist(gray)

plt.imshow(eq, cmap='gray')
plt.title("Equalização de Histograma")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %%
## Exercício 20 - Descrição
_, th = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

plt.imshow(th, cmap='gray')
plt.title("Threshold binário")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))
